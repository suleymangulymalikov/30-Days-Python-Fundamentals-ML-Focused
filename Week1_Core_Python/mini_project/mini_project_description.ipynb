# %% [markdown]
# **Build a Basic Contact Book App** (CRUD operations)
#
# Build a dictionary-based contact book that allows:
#
# - Add contact
# - Remove contact
# - View all contacts
# - Search contact
#
#     Just print-based interaction.
