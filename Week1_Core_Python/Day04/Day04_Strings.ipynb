# %% [markdown]
# # Strings

# %% [markdown]
# Learn:
# - slicing
# - methods (split, join, replace, upper/lower)
# - formatting

# %% [markdown]
# Strings in python are surrounded by either single quotation marks, or double quotation marks.
#
# `'hello'` is the same as `"hello"`.
#
# You can display a string literal with the print() function:

# %%
# Assign String to variable
a = "Hello World"

# Single line String
print("Hello World")

# Quotes Inside Quotes
print("It's alright")
print("He is called 'Johnny'")
print('He is called "Johnny"')

# Multiline Strings
b = """
Lorem ipsum dolor sit amet,
consectetur adipiscing elit,
sed do eiusmod tempor incididunt
ut labore et dolore magna aliqua.
"""
print(b)
# Out:
# Hello World
# It's alright
# He is called 'Johnny'
# He is called "Johnny"
#
# Lorem ipsum dolor sit amet,
# consectetur adipiscing elit,
# sed do eiusmod tempor incididunt
# ut labore et dolore magna aliqua.

# %% [markdown]
# ## Slicing

# %% [markdown]
# You can return a range of characters by using the slice syntax.
# Specify the start index and the end index, separated by a colon, to return a part of the string.
#
# Example:
#
# *Get the character from the position 2 to position 5(5 is not included)*

# %%
b = "Hello, World!"
print(b[2:5])

# Slice from the Start
print(b[:5])

# Slice to the End
print(b[2:])

# Negative Indexing
print(b[-5:-2])
# Out:
# llo
# Hello
# llo, World!
# orl

# %% [markdown]
# [more about Slicing](https://www.w3schools.com/python/python_strings_slicing.asp)

# %% [markdown]
# ## Formatting

# %% [markdown]
# As we learned in the Python Variables chapter, we cannot combine strings and numbers like this:

# %%
age = 36
#This will produce an error:
txt = "My name is John, I am " + age
print(txt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 age = 36
#       2 #This will produce an error:
# ----> 3 txt = "My name is John, I am " + age
#       4 print(txt)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# But we can combine strings and numbers by using f-strings or the `format()` method!

# %% [markdown]
# **F-Strings**

# %% [markdown]
# F-String was introduced in Python 3.6, and is now the preferred way of formatting strings.
#
# To specify a string as an f-string, simply put an `f` in front of the string literal, and add curly brackets `{}`as placeholders for variables and other operations.

# %%
age = 36
txt = f"My name is John, I am {age}"
print(txt)
# Out:
# My name is John, I am 36

# %% [markdown]
# **Placeholders and Modifiers**
#
# A placeholder can contain variables, operations, functions, and modifiers to format the value.

# %%
price = 59
txt = f"The price is {price} dollars"
print(txt)
# Out:
# The price is 59 dollars

# %% [markdown]
# A placeholder can include a modifier to format the value.
#
# A modifier is included by adding a colon `:` followed by a legal formatting type, like `.2f` which means fixed point number with 2 decimals:

# %%
price = 59
txt = f"The price is {price:.2f} dollars"
print(txt)
# Out:
# The price is 59.00 dollars

# %% [markdown]
# A placeholder can contain Python code, like math operations:

# %%
txt = f"The price is {20 * 59} dollars"
print(txt)
# Out:
# The price is 1180 dollars

# %% [markdown]
# [more about Formatting](https://www.w3schools.com/python/python_strings_format.asp)

# %% [markdown]
# ## Methods

# %% [markdown]
# - `capitalize()`  -   Converts the first character to upper case
# - `join()`        -   Joints the elements of an iterable to the end of the string
# - `lower()`       -   Converts a string into lower case
# - `replace()`     -   Returns a string where a specified value is replaced with a specified value
# - `split()`       -   Splits the string at line breaks and returns a list
# - `strip()`       -   Returns a trimmed version of the string
# - `upper()`       -   Converts a string into upper case

# %% [markdown]
# [for more about String methods](https://www.w3schools.com/python/python_strings_methods.asp)

# %% [markdown]
# # Task - Text Cleaner

# %% [markdown]
# You will take a messy paragraph and turn it into a clean, properly formatted one.
#
# The messy paragraph may contain:
# - random capitalization
# - too many spaces
# - unwanted words
# - inconsistent formatting

# %% [markdown]
# **Your program should**
#
# 1. Remove Extra Space
# 2. Fix letter casing
# 3. Replace unwanted words
#
#
# Example Input:
#
# `"   hELLo     WoRLD   !!!   this   is    a tESt. btw, u are great   "`
#
# Example Output:
#
# `"Hello world!!! This is a test. By the way, you are great"`
